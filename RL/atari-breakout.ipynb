# %%
from dqn.dqn_atari import dqn_atari, breakout_process, save, load_all_stats
from utils.plots import draw

# %%
nn1, rewards1, qs1, losses1 = dqn_atari('BreakoutNoFrameskip-v4', breakout_process,
                                   last_100_av_reward_to_win = 60.)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:134: RuntimeWarning: Mean of empty slice.
# D:\anaconda\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# episode: 100 total reward: 3.0 eps: 1.0
# avg reward/clipped (last 100): 1.5643564356435644 / 1.504950495049505
# avg loss(last 100): nan
# time: 90.53176927566528 seconds total weights updates: 0
# -------------------------------------------------------------------------
# minimum experience gained on episode 101 . Training started
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1394: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# episode: 200 total reward: 0.0 eps: 0.9836164000005394
# ...

# %%
nn2, rewards2, qs2, losses2 = dqn_atari('BreakoutNoFrameskip-v4', breakout_process,
                                   last_100_av_reward_to_win = 60.)
# Out:
# minimum experience gained on episode 99 . Training started
# episode: 100 total reward: 2.0 eps: 0.9997030000000098
# avg reward/clipped (last 100): 1.6435643564356435 / 1.6435643564356435
# avg loss(last 100): 0.008192248031636703
# time: 76.17510604858398 seconds total weights updates: 83
# -------------------------------------------------------------------------
# episode: 200 total reward: 0.0 eps: 0.982718200000569
# avg reward/clipped (last 100): 1.306930693069307 / 1.2772277227722773
# avg loss(last 100): 0.00545783032677971
# time: 275.64106369018555 seconds total weights updates: 4801
# -------------------------------------------------------------------------
# episode: 300 total reward: 2.0 eps: 0.96689170000109
# avg reward/clipped (last 100): 1.0198019801980198 / 1.0198019801980198
# avg loss(last 100): 0.004501663211860168
# time: 267.47210216522217 seconds total weights updates: 9197
# -------------------------------------------------------------------------
# ...

# %%
nn3, rewards3, qs3, losses3 = dqn_atari('BreakoutNoFrameskip-v4', breakout_process,
                                   last_100_av_reward_to_win = 60.)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:134: RuntimeWarning: Mean of empty slice.
# D:\anaconda\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# episode: 100 total reward: 1.0 eps: 1.0
# avg reward/clipped (last 100): 1.2376237623762376 / 1.2376237623762376
# avg loss(last 100): nan
# time: 68.50474190711975 seconds total weights updates: 0
# -------------------------------------------------------------------------
# minimum experience gained on episode 106 . Training started
# episode: 200 total reward: 1.0 eps: 0.9832897000005502
# avg reward/clipped (last 100): 1.5544554455445545 / 1.5247524752475248
# avg loss(last 100): 0.005059526030715478
# time: 276.84938859939575 seconds total weights updates: 4642
# -------------------------------------------------------------------------
# episode: 300 total reward: 1.0 eps: 0.9661447000011146
# ...

# %%
nn4, rewards4, qs4, losses4 = dqn_atari('BreakoutNoFrameskip-v4', breakout_process,
                                   last_100_av_reward_to_win = 60.)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:134: RuntimeWarning: Mean of empty slice.
# D:\anaconda\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# episode: 100 total reward: 3.0 eps: 1.0
# avg reward/clipped (last 100): 1.1782178217821782 / 1.1782178217821782
# avg loss(last 100): nan
# time: 72.58816647529602 seconds total weights updates: 0
# -------------------------------------------------------------------------
# minimum experience gained on episode 108 . Training started
# episode: 200 total reward: 1.0 eps: 0.9848638000004983
# avg reward/clipped (last 100): 1.188118811881188 / 1.188118811881188
# avg loss(last 100): 0.0059938845330767465
# time: 252.2709412574768 seconds total weights updates: 4205
# -------------------------------------------------------------------------
# episode: 300 total reward: 0.0 eps: 0.9682489000010454
# ...

# %%
nn5, rewards5, qs5, losses5 = dqn_atari('BreakoutNoFrameskip-v4', breakout_process,
                                   last_100_av_reward_to_win = 60.)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:134: RuntimeWarning: Mean of empty slice.
# D:\anaconda\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# episode: 100 total reward: 4.0 eps: 1.0
# avg reward/clipped (last 100): 1.0495049504950495 / 1.0495049504950495
# avg loss(last 100): nan
# time: 63.53904390335083 seconds total weights updates: 0
# -------------------------------------------------------------------------
# minimum experience gained on episode 113 . Training started
# episode: 200 total reward: 0.0 eps: 0.9855892000004745
# avg reward/clipped (last 100): 1.1683168316831682 / 1.1386138613861385
# avg loss(last 100): 0.004877479571524464
# time: 231.04061889648438 seconds total weights updates: 4003
# -------------------------------------------------------------------------
# episode: 300 total reward: 1.0 eps: 0.9692821000010113
# ...

# %%
nn6, rewards6, qs6, losses6 = dqn_atari('BreakoutNoFrameskip-v4', breakout_process,
                                   last_100_av_reward_to_win = 60.)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:134: RuntimeWarning: Mean of empty slice.
# D:\anaconda\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# episode: 100 total reward: 0.0 eps: 1.0
# avg reward/clipped (last 100): 1.5148514851485149 / 1.4851485148514851
# avg loss(last 100): nan
# time: 85.09786939620972 seconds total weights updates: 0
# -------------------------------------------------------------------------
# minimum experience gained on episode 102 . Training started
# episode: 200 total reward: 1.0 eps: 0.9827200000005689
# avg reward/clipped (last 100): 1.5346534653465347 / 1.4455445544554455
# avg loss(last 100): 0.005909319747610608
# time: 323.3697235584259 seconds total weights updates: 4800
# -------------------------------------------------------------------------
# episode: 300 total reward: 0.0 eps: 0.9657667000011271
# ...

# %%
nn7, rewards7, qs7, losses7 = dqn_atari('BreakoutNoFrameskip-v4', breakout_process,
                                   last_100_av_reward_to_win = 60.)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:134: RuntimeWarning: Mean of empty slice.
# D:\anaconda\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# episode: 100 total reward: 9.0 eps: 1.0
# avg reward/clipped (last 100): 1.2475247524752475 / 1.2178217821782178
# avg loss(last 100): nan
# time: 75.19250583648682 seconds total weights updates: 0
# -------------------------------------------------------------------------
# minimum experience gained on episode 108 . Training started
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1394: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# episode: 200 total reward: 4.0 eps: 0.9843742000005145
# ...

# %%
nn8, rewards8, qs8, losses8 = dqn_atari('BreakoutNoFrameskip-v4', breakout_process,
                                   last_100_av_reward_to_win = 60.)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:134: RuntimeWarning: Mean of empty slice.
# D:\anaconda\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# episode: 100 total reward: 0.0 eps: 1.0
# avg reward/clipped (last 100): 1.2079207920792079 / 1.2079207920792079
# avg loss(last 100): nan
# time: 68.83343243598938 seconds total weights updates: 0
# -------------------------------------------------------------------------
# minimum experience gained on episode 108 . Training started
# episode: 200 total reward: 0.0 eps: 0.9851698000004883
# avg reward/clipped (last 100): 1.0891089108910892 / 1.0891089108910892
# avg loss(last 100): 0.005551724537148586
# time: 246.47820401191711 seconds total weights updates: 4120
# -------------------------------------------------------------------------
# episode: 300 total reward: 0.0 eps: 0.9680833000010508
# ...

# %%
nn9, rewards9, qs9, losses9 = dqn_atari('BreakoutNoFrameskip-v4', breakout_process,
                                   last_100_av_reward_to_win = 60.)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:134: RuntimeWarning: Mean of empty slice.
# D:\anaconda\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# episode: 100 total reward: 0.0 eps: 1.0
# avg reward/clipped (last 100): 1.1485148514851484 / 1.118811881188119
# avg loss(last 100): nan
# time: 62.85351490974426 seconds total weights updates: 0
# -------------------------------------------------------------------------
# minimum experience gained on episode 109 . Training started
# episode: 200 total reward: 1.0 eps: 0.9849763000004946
# avg reward/clipped (last 100): 1.2376237623762376 / 1.2376237623762376
# avg loss(last 100): 0.005880782560112738
# time: 235.91699528694153 seconds total weights updates: 4174
# -------------------------------------------------------------------------
# episode: 300 total reward: 2.0 eps: 0.9681265000010494
# ...

# %%
savings = 'savings/breakout'

# %%
save(savings, 1, nn1, rewards1, qs1, losses1)

# %%
save(savings, 2, nn2, rewards2, qs2, losses2)

# %%
save(savings, 3, nn3, rewards3, qs3, losses3)

# %%
save(savings, 4, nn4, rewards4, qs4, losses4)

# %%
save(savings, 5, nn5, rewards5, qs5, losses5)

# %%
save(savings, 6, nn6, rewards6, qs6, losses6)

# %%
save(savings, 7, nn7, rewards7, qs7, losses7)

# %%
save(savings, 8, nn8, rewards8, qs8, losses8)

# %%
save(savings, 9, nn9, rewards9, qs9, losses9)

# %%
all_rewards, all_qs, all_losses = load_all_stats(savings)

# %%
draw('reward', all_rewards)

# %%
draw('max q-value', all_qs)

# %%
draw('loss', all_losses)
