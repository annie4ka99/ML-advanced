# %%
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow_datasets as tfds

import numpy as np
import os
import time
import re

# %%
path_to_file = tf.keras.utils.get_file('alice_in_wonderland.txt', 'https://gist.githubusercontent.com/phillipj/4944029/raw/75ba2243dd5ec2875f629bf5d79f6c1e4b5a8b46/alice_in_wonderland.txt')
# Out:
# Downloading data from https://gist.githubusercontent.com/phillipj/4944029/raw/75ba2243dd5ec2875f629bf5d79f6c1e4b5a8b46/alice_in_wonderland.txt
# 155648/148574 [===============================] - 0s 0us/step

# %%
text = open(path_to_file, 'rb').read().decode(encoding='utf-8')

# %%
text = text[180:]
print(text[:500])
# Out:
#                            CHAPTER I
#
#                       Down the Rabbit-Hole
#
#
#   Alice was beginning to get very tired of sitting by her sister
# on the bank, and of having nothing to do:  once or twice she had
# peeped into the book her sister was reading, but it had no
# pictures or conversations in it, `and what is the use of a book,'
# thought Alice `without pictures or conversation?'
#
#   So she was considering in her own mind (as well as she could,
# for the hot day made her feel very sleepy and s

# %%
def preprocess(text):
    res = text.lower()
    res = re.sub('chapter\s+\w+\s+[\w\-\' ?]+\n+', '', res)
    res = re.sub('^\s+', '' ,res)
    res = re.sub('\n', ' ', res)
    res = re.sub(' +', ' ', res)
    res = re.sub('(\*\s*)+', '', res)
    res = re.sub('[\'\"\[\]`_]', '', res)
    res = re.sub('[?!;:]', '.', res)
    res = re.sub('[\(\)]', ',', res)
    res = re.sub('--', ',', res)
    return res

# %%
processed_text = preprocess(text)
print(processed_text[:100])
print(f'\nLength of preprocessed text: {len(processed_text)} characters')
# Out:
# alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to
#
# Length of preprocessed text: 138632 characters

# %%
maxlen = 132

# %%
init_lines = processed_text.split('.')

lines = []
for line in init_lines:
    if len(line) <= maxlen:
        lines.append(line + '.')
        continue
    parts = line.split(',')
    buf = ""
    for part in parts:
        if len(buf) + len(part) + 1 <= maxlen:
            buf += ("," + part)
        else:
            lines.append(buf + '.')
            buf = part

# %%
vocab = list(sorted(set(processed_text)))
vocab = ['*'] + vocab
print(f'{len(vocab)} unique characters')
# Out:
# 31 unique characters

# %%
vocab_size = len(vocab)
input_len = maxlen - 1
batch_size = 128
end_char_num = vocab.index('.')

# %%
encode = {vocab[i]:i for i in range(vocab_size)}

encoded_lines = np.array([[encode[line[i]] if i < len(line) else 0  for i in range(maxlen)] 
                          for line in lines])

x = [line[:-1] for line in encoded_lines]
y = [line[1:] for line in encoded_lines]

ds = tf.data.Dataset.from_tensor_slices((x, y))
ds = ds.batch(batch_size)

# %%
def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
    return pos * angle_rates

# %%
def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                            np.arange(d_model)[np.newaxis, :],
                            d_model)

    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
class OneHotAndPositionEmbedding(layers.Layer):
    def __init__(self, max_len, vocab_size):
        super(OneHotAndPositionEmbedding, self).__init__()
        self.pos_enc = positional_encoding(max_len, vocab_size)
        self.vocab_size = vocab_size

    def call(self, x):
        seq_len = tf.shape(x)[-1]
        x = tf.one_hot(x, self.vocab_size)
        positions = self.pos_enc[:, :seq_len, :]
        return x + positions

# %%
def causal_attention_mask(batch_size, n_dest, n_src, dtype):
    i = tf.range(n_dest)[:, None]
    j = tf.range(n_src)
    m = i >= j - n_src + n_dest
    mask = tf.cast(m, dtype)
    mask = tf.reshape(mask, [1, n_dest, n_src])
    mult = tf.concat(
        [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0
    )
    return tf.tile(mask, mult)


class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads, embed_dim)
        self.ffn = tf.keras.Sequential(
            [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = causal_attention_mask(batch_size, seq_len, seq_len, tf.bool)
        attention_output = self.att(inputs, inputs, attention_mask=causal_mask)
        attention_output = self.dropout1(attention_output)
        out1 = self.layernorm1(inputs + attention_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        return self.layernorm2(out1 + ffn_output)

# %%
num_heads = 8
feed_forward_dim = 256

def create_model():
    inputs = layers.Input(shape=(input_len,), dtype=tf.int32)
    embedding_layer = OneHotAndPositionEmbedding(input_len, vocab_size)
    x = embedding_layer(inputs)
    transformer_block1 = TransformerBlock(vocab_size, num_heads, feed_forward_dim)
    x = transformer_block1(x)
    transformer_block2 = TransformerBlock(vocab_size, num_heads, feed_forward_dim)
    x = transformer_block2(x)
    transformer_block3 = TransformerBlock(vocab_size, num_heads, feed_forward_dim)
    x = transformer_block3(x)
    transformer_block4 = TransformerBlock(vocab_size, num_heads, feed_forward_dim)
    x = transformer_block4(x)
    outputs = layers.Dense(vocab_size)(x)
    model = tf.keras.Model(inputs=inputs, outputs=[outputs, x])
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    model.compile(
        "adam", loss=[loss_fn, None],
    )  # No loss and optimization based on word embeddings from transformer block
    return model

# %%
class TextGenerator(tf.keras.callbacks.Callback):
    def __init__(
        self, max_tokens, start_tokens, vocab, top_k=5, print_every=1
    ):
        self.max_tokens = max_tokens
        self.start_tokens = start_tokens
        self.vocab = vocab
        self.print_every = print_every
        self.k = top_k

    def sample_from(self, logits):
        logits, indices = tf.math.top_k(logits, k=self.k, sorted=True)
        indices = np.asarray(indices).astype("int32")
        preds = tf.keras.activations.softmax(tf.expand_dims(logits, 0))[0]
        preds = np.asarray(preds).astype("float32")
        return np.random.choice(indices, p=preds)

    def detokenize(self, number):
        return self.vocab[number]

    def on_epoch_end(self, epoch, logs=None):
        start_tokens = [_ for _ in self.start_tokens]
        if (epoch + 1) % self.print_every != 0:
            return
        num_tokens_generated = 0
        tokens_generated = []
        while (num_tokens_generated <= self.max_tokens and 
               (len(tokens_generated) == 0 or 
                (tokens_generated[-1] != end_char_num and
                tokens_generated[-1] != 0))):
            pad_len = input_len - len(start_tokens)
            sample_index = len(start_tokens) - 1
            if pad_len < 0:
                x = start_tokens[:input_len]
                sample_index = input_len - 1
            elif pad_len > 0:
                x = start_tokens + [0] * pad_len
            else:
                x = start_tokens
            x = np.array([x])
            y, _ = self.model.predict(x)
            sample_token = self.sample_from(y[0][sample_index])
            tokens_generated.append(sample_token)
            start_tokens.append(sample_token)
            num_tokens_generated = len(tokens_generated)
        txt = "".join(
            [self.detokenize(_) for _ in self.start_tokens + tokens_generated]
        )
        print(f"generated text:\n{txt}\n")

# %%
line_start = "after a time "
start_tokens = [encode[char] for char in line_start]
text_gen_callback = TextGenerator(maxlen, start_tokens, vocab, print_every=10)

# %%
model = create_model()

# one decoder, 3 attention heads
model.fit(ds, verbose=1, epochs=500, callbacks=[text_gen_callback])
# Out:
# Epoch 1/500
# 17/17 [==============================] - 6s 64ms/step - loss: 2.0632 - dense_60_loss: 2.0632
# Epoch 2/500
# 17/17 [==============================] - 1s 59ms/step - loss: 1.6321 - dense_60_loss: 1.6321
# Epoch 3/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.4886 - dense_60_loss: 1.4886
# Epoch 4/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.4120 - dense_60_loss: 1.4120
# Epoch 5/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.3849 - dense_60_loss: 1.3849
# Epoch 6/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.3655 - dense_60_loss: 1.3655
# Epoch 7/500
# 17/17 [==============================] - 1s 61ms/step - loss: 1.3481 - dense_60_loss: 1.3481
# Epoch 8/500
# 17/17 [==============================] - 1s 59ms/step - loss: 1.3295 - dense_60_loss: 1.3295
# Epoch 9/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.2998 - dense_60_loss: 1.2998
# Epoch 10/500
# 17/17 [==============================] - 1s 61ms/step - loss: 1.2743 - dense_60_loss: 1.2743
# generated text:
# after a time stharend e e int  a het i hedo o t   ot se  and  t asngert o inet ond be eeee*
#
# Epoch 11/500
# 17/17 [==============================] - 1s 63ms/step - loss: 1.2451 - dense_60_loss: 1.2451
# Epoch 12/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.2169 - dense_60_loss: 1.2169
# Epoch 13/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.1900 - dense_60_loss: 1.1900
# Epoch 14/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.1663 - dense_60_loss: 1.1663
# Epoch 15/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.1451 - dense_60_loss: 1.1451
# Epoch 16/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.1273 - dense_60_loss: 1.1273
# Epoch 17/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.1125 - dense_60_loss: 1.1125
# Epoch 18/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.1019 - dense_60_loss: 1.1019
# Epoch 19/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.0929 - dense_60_loss: 1.0929
# Epoch 20/500
# 17/17 [==============================] - 1s 61ms/step - loss: 1.0844 - dense_60_loss: 1.0844
# generated text:
# after a time in a in s shed thedo tor atese t so an the shan thedr that thes the athe arone s wailer went owaon aoule t s t nd.
#
# Epoch 21/500
# 17/17 [==============================] - 1s 64ms/step - loss: 1.0770 - dense_60_loss: 1.0770
# Epoch 22/500
# 17/17 [==============================] - 1s 61ms/step - loss: 1.0713 - dense_60_loss: 1.0713
# Epoch 23/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.0659 - dense_60_loss: 1.0659
# Epoch 24/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.0595 - dense_60_loss: 1.0595
# Epoch 25/500
# 17/17 [==============================] - 1s 61ms/step - loss: 1.0536 - dense_60_loss: 1.0536
# Epoch 26/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.0484 - dense_60_loss: 1.0484
# Epoch 27/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.0439 - dense_60_loss: 1.0439
# Epoch 28/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.0395 - dense_60_loss: 1.0395
# Epoch 29/500
# 17/17 [==============================] - 1s 61ms/step - loss: 1.0340 - dense_60_loss: 1.0340
# Epoch 30/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.0257 - dense_60_loss: 1.0257
# generated text:
# after a time he tout and the wher are hesthing tha whe t o we t ithe thisth aryere s tinge she wou onert o storyour thisha ti t  .
#
# Epoch 31/500
# 17/17 [==============================] - 1s 62ms/step - loss: 1.0198 - dense_60_loss: 1.0198
# Epoch 32/500
# 17/17 [==============================] - 1s 60ms/step - loss: 1.0150 - dense_60_loss: 1.0150
# Epoch 33/500
# 17/17 [==============================] - 1s 61ms/step - loss: 1.0084 - dense_60_loss: 1.0084
# Epoch 34/500
# 17/17 [==============================] - 1s 61ms/step - loss: 1.0034 - dense_60_loss: 1.0034
# Epoch 35/500
# 17/17 [==============================] - 1s 60ms/step - loss: 0.9974 - dense_60_loss: 0.9974
# Epoch 36/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9912 - dense_60_loss: 0.9912
# Epoch 37/500
# 17/17 [==============================] - 1s 60ms/step - loss: 0.9859 - dense_60_loss: 0.9859
# Epoch 38/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9804 - dense_60_loss: 0.9804
# Epoch 39/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.9753 - dense_60_loss: 0.9753
# Epoch 40/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9706 - dense_60_loss: 0.9706
# generated text:
# after a time wated sat the shin thare she ar sho toous, whe.
#
# Epoch 41/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.9653 - dense_60_loss: 0.9653
# Epoch 42/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9605 - dense_60_loss: 0.9605
# Epoch 43/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.9561 - dense_60_loss: 0.9561
# Epoch 44/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9502 - dense_60_loss: 0.9502
# Epoch 45/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9449 - dense_60_loss: 0.9449
# Epoch 46/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.9404 - dense_60_loss: 0.9404
# Epoch 47/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9366 - dense_60_loss: 0.9366
# Epoch 48/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9327 - dense_60_loss: 0.9327
# Epoch 49/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.9274 - dense_60_loss: 0.9274
# Epoch 50/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9223 - dense_60_loss: 0.9223
# generated text:
# after a time shas a said seay.
#
# Epoch 51/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.9175 - dense_60_loss: 0.9175
# Epoch 52/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.9137 - dense_60_loss: 0.9137
# Epoch 53/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9108 - dense_60_loss: 0.9108
# Epoch 54/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.9060 - dense_60_loss: 0.9060
# Epoch 55/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.9019 - dense_60_loss: 0.9019
# Epoch 56/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.8988 - dense_60_loss: 0.8988
# Epoch 57/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8961 - dense_60_loss: 0.8961
# Epoch 58/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8911 - dense_60_loss: 0.8911
# Epoch 59/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8871 - dense_60_loss: 0.8871
# Epoch 60/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.8828 - dense_60_loss: 0.8828
# generated text:
# after a time wass it to the saile has, saice a the abimppenin a aliong said in wis she alice.
#
# Epoch 61/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.8786 - dense_60_loss: 0.8786
# Epoch 62/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.8750 - dense_60_loss: 0.8750
# Epoch 63/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8706 - dense_60_loss: 0.8706
# Epoch 64/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8682 - dense_60_loss: 0.8682
# Epoch 65/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8647 - dense_60_loss: 0.8647
# Epoch 66/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.8633 - dense_60_loss: 0.8633
# Epoch 67/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8574 - dense_60_loss: 0.8574
# Epoch 68/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8545 - dense_60_loss: 0.8545
# Epoch 69/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.8504 - dense_60_loss: 0.8504
# Epoch 70/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8470 - dense_60_loss: 0.8470
# generated text:
# after a time to so the creat wite saiong, to whange hat and to hem ton whing ther shers wall to here thong to age there thery sen.
#
# Epoch 71/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.8430 - dense_60_loss: 0.8430
# Epoch 72/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.8405 - dense_60_loss: 0.8405
# Epoch 73/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.8385 - dense_60_loss: 0.8385
# Epoch 74/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8366 - dense_60_loss: 0.8366
# Epoch 75/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8328 - dense_60_loss: 0.8328
# Epoch 76/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8287 - dense_60_loss: 0.8287
# Epoch 77/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8259 - dense_60_loss: 0.8259
# Epoch 78/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.8235 - dense_60_loss: 0.8235
# Epoch 79/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8198 - dense_60_loss: 0.8198
# Epoch 80/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8174 - dense_60_loss: 0.8174
# generated text:
# after a time i all and thing ast, ale the wely.
#
# Epoch 81/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8132 - dense_60_loss: 0.8132
# Epoch 82/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8106 - dense_60_loss: 0.8106
# Epoch 83/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8090 - dense_60_loss: 0.8090
# Epoch 84/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8060 - dense_60_loss: 0.8060
# Epoch 85/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.8035 - dense_60_loss: 0.8035
# Epoch 86/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7998 - dense_60_loss: 0.7998
# Epoch 87/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7978 - dense_60_loss: 0.7978
# Epoch 88/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7938 - dense_60_loss: 0.7938
# Epoch 89/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7926 - dense_60_loss: 0.7926
# Epoch 90/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7905 - dense_60_loss: 0.7905
# generated text:
# after a time the crigstainged the said tome the gore of to to he cour andeal tupteaing of the door thrigs.
#
# Epoch 91/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.7863 - dense_60_loss: 0.7863
# Epoch 92/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7852 - dense_60_loss: 0.7852
# Epoch 93/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7830 - dense_60_loss: 0.7830
# Epoch 94/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7788 - dense_60_loss: 0.7788
# Epoch 95/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7772 - dense_60_loss: 0.7772
# Epoch 96/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7762 - dense_60_loss: 0.7762
# Epoch 97/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7731 - dense_60_loss: 0.7731
# Epoch 98/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7745 - dense_60_loss: 0.7745
# Epoch 99/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7718 - dense_60_loss: 0.7718
# Epoch 100/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7712 - dense_60_loss: 0.7712
# generated text:
# after a time to the gat the she goor his cater alice, and when tayill to she where what they sping to hee thing wer way a trer ar.
#
# Epoch 101/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7681 - dense_60_loss: 0.7681
# Epoch 102/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.7639 - dense_60_loss: 0.7639
# Epoch 103/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7607 - dense_60_loss: 0.7607
# Epoch 104/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7595 - dense_60_loss: 0.7595
# Epoch 105/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7569 - dense_60_loss: 0.7569
# Epoch 106/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.7551 - dense_60_loss: 0.7551
# Epoch 107/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7546 - dense_60_loss: 0.7546
# Epoch 108/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7520 - dense_60_loss: 0.7520
# Epoch 109/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7498 - dense_60_loss: 0.7498
# Epoch 110/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7460 - dense_60_loss: 0.7460
# generated text:
# after a time the hat we hard the down them she her had she some, the gleet the co he was hout on the cats a stid to bee wo to sean   .
#
# Epoch 111/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7445 - dense_60_loss: 0.7445
# Epoch 112/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7423 - dense_60_loss: 0.7423
# Epoch 113/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7394 - dense_60_loss: 0.7394
# Epoch 114/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7376 - dense_60_loss: 0.7376
# Epoch 115/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7363 - dense_60_loss: 0.7363
# Epoch 116/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7330 - dense_60_loss: 0.7330
# Epoch 117/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7326 - dense_60_loss: 0.7326
# Epoch 118/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7326 - dense_60_loss: 0.7326
# Epoch 119/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7296 - dense_60_loss: 0.7296
# Epoch 120/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7285 - dense_60_loss: 0.7285
# generated text:
# after a time i cat to hem see of think, and the she was tush to last the dor simpeall abbind.
#
# Epoch 121/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.7278 - dense_60_loss: 0.7278
# Epoch 122/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7259 - dense_60_loss: 0.7259
# Epoch 123/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7257 - dense_60_loss: 0.7257
# Epoch 124/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.7228 - dense_60_loss: 0.7228
# Epoch 125/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7212 - dense_60_loss: 0.7212
# Epoch 126/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7204 - dense_60_loss: 0.7204
# Epoch 127/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7178 - dense_60_loss: 0.7178
# Epoch 128/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7167 - dense_60_loss: 0.7167
# Epoch 129/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7158 - dense_60_loss: 0.7158
# Epoch 130/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7138 - dense_60_loss: 0.7138
# generated text:
# after a time thats is the gar.
#
# Epoch 131/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7126 - dense_60_loss: 0.7126
# Epoch 132/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7103 - dense_60_loss: 0.7103
# Epoch 133/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7097 - dense_60_loss: 0.7097
# Epoch 134/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.7084 - dense_60_loss: 0.7084
# Epoch 135/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7050 - dense_60_loss: 0.7050
# Epoch 136/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7036 - dense_60_loss: 0.7036
# Epoch 137/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.7041 - dense_60_loss: 0.7041
# Epoch 138/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7012 - dense_60_loss: 0.7012
# Epoch 139/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7011 - dense_60_loss: 0.7011
# Epoch 140/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7011 - dense_60_loss: 0.7011
# generated text:
# after a time hatter that alice.
#
# Epoch 141/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6990 - dense_60_loss: 0.6990
# Epoch 142/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6969 - dense_60_loss: 0.6969
# Epoch 143/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6960 - dense_60_loss: 0.6960
# Epoch 144/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6946 - dense_60_loss: 0.6946
# Epoch 145/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6949 - dense_60_loss: 0.6949
# Epoch 146/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6919 - dense_60_loss: 0.6919
# Epoch 147/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6911 - dense_60_loss: 0.6911
# Epoch 148/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6895 - dense_60_loss: 0.6895
# Epoch 149/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6897 - dense_60_loss: 0.6897
# Epoch 150/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6893 - dense_60_loss: 0.6893
# generated text:
# after a time the dister which the waite too said herself to, and the kes as of out on to the was tith hear and soort.
#
# Epoch 151/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.6876 - dense_60_loss: 0.6876
# Epoch 152/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6867 - dense_60_loss: 0.6867
# Epoch 153/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6845 - dense_60_loss: 0.6845
# Epoch 154/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6846 - dense_60_loss: 0.6846
# Epoch 155/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6823 - dense_60_loss: 0.6823
# Epoch 156/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6819 - dense_60_loss: 0.6819
# Epoch 157/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6805 - dense_60_loss: 0.6805
# Epoch 158/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6799 - dense_60_loss: 0.6799
# Epoch 159/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6816 - dense_60_loss: 0.6816
# Epoch 160/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6786 - dense_60_loss: 0.6786
# generated text:
# after a time it his thing or whis and the got alice, and was weal the go two then sat the goody had any talke a the dars.
#
# Epoch 161/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6781 - dense_60_loss: 0.6781
# Epoch 162/500
# 17/17 [==============================] - 1s 61ms/step - loss: 0.6766 - dense_60_loss: 0.6766
# Epoch 163/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6737 - dense_60_loss: 0.6737
# Epoch 164/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6736 - dense_60_loss: 0.6736
# Epoch 165/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6723 - dense_60_loss: 0.6723
# Epoch 166/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6709 - dense_60_loss: 0.6709
# Epoch 167/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6722 - dense_60_loss: 0.6722
# Epoch 168/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6700 - dense_60_loss: 0.6700
# Epoch 169/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6695 - dense_60_loss: 0.6695
# Epoch 170/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6688 - dense_60_loss: 0.6688
# generated text:
# after a time though welf, say in the con his to the gryphout it a them the litto of same ance the sigh, worder.
#
# Epoch 171/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6672 - dense_60_loss: 0.6672
# Epoch 172/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6672 - dense_60_loss: 0.6672
# Epoch 173/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6667 - dense_60_loss: 0.6667
# Epoch 174/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6659 - dense_60_loss: 0.6659
# Epoch 175/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6634 - dense_60_loss: 0.6634
# Epoch 176/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6624 - dense_60_loss: 0.6624
# Epoch 177/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6633 - dense_60_loss: 0.6633
# Epoch 178/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6604 - dense_60_loss: 0.6604
# Epoch 179/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6604 - dense_60_loss: 0.6604
# Epoch 180/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6592 - dense_60_loss: 0.6592
# generated text:
# after a time she head a back.
#
# Epoch 181/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6598 - dense_60_loss: 0.6598
# Epoch 182/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6590 - dense_60_loss: 0.6590
# Epoch 183/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6582 - dense_60_loss: 0.6582
# Epoch 184/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6589 - dense_60_loss: 0.6589
# Epoch 185/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6590 - dense_60_loss: 0.6590
# Epoch 186/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6572 - dense_60_loss: 0.6572
# Epoch 187/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6566 - dense_60_loss: 0.6566
# Epoch 188/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6531 - dense_60_loss: 0.6531
# Epoch 189/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6550 - dense_60_loss: 0.6550
# Epoch 190/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6550 - dense_60_loss: 0.6550
# generated text:
# after a time a course.
#
# Epoch 191/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6531 - dense_60_loss: 0.6531
# Epoch 192/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6511 - dense_60_loss: 0.6511
# Epoch 193/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6488 - dense_60_loss: 0.6488
# Epoch 194/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6492 - dense_60_loss: 0.6492
# Epoch 195/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6466 - dense_60_loss: 0.6466
# Epoch 196/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6466 - dense_60_loss: 0.6466
# Epoch 197/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6482 - dense_60_loss: 0.6482
# Epoch 198/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6473 - dense_60_loss: 0.6473
# Epoch 199/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6481 - dense_60_loss: 0.6481
# Epoch 200/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6483 - dense_60_loss: 0.6483
# generated text:
# after a time the patting, and the righols, as a longry was so the ploces.
#
# Epoch 201/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.6444 - dense_60_loss: 0.6444
# Epoch 202/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6444 - dense_60_loss: 0.6444
# Epoch 203/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6417 - dense_60_loss: 0.6417
# Epoch 204/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6431 - dense_60_loss: 0.6431
# Epoch 205/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6411 - dense_60_loss: 0.6411
# Epoch 206/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6394 - dense_60_loss: 0.6394
# Epoch 207/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6393 - dense_60_loss: 0.6393
# Epoch 208/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6391 - dense_60_loss: 0.6391
# Epoch 209/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6390 - dense_60_loss: 0.6390
# Epoch 210/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6393 - dense_60_loss: 0.6393
# generated text:
# after a time the mock turtles of the dight.
#
# Epoch 211/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6363 - dense_60_loss: 0.6363
# Epoch 212/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6355 - dense_60_loss: 0.6355
# Epoch 213/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6335 - dense_60_loss: 0.6335
# Epoch 214/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6335 - dense_60_loss: 0.6335
# Epoch 215/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6326 - dense_60_loss: 0.6326
# Epoch 216/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6325 - dense_60_loss: 0.6325
# Epoch 217/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6308 - dense_60_loss: 0.6308
# Epoch 218/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6314 - dense_60_loss: 0.6314
# Epoch 219/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6289 - dense_60_loss: 0.6289
# Epoch 220/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6294 - dense_60_loss: 0.6294
# generated text:
# after a time the reached, this sat or the ristless alice.
#
# Epoch 221/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6295 - dense_60_loss: 0.6295
# Epoch 222/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6295 - dense_60_loss: 0.6295
# Epoch 223/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6302 - dense_60_loss: 0.6302
# Epoch 224/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6282 - dense_60_loss: 0.6282
# Epoch 225/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6273 - dense_60_loss: 0.6273
# Epoch 226/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6270 - dense_60_loss: 0.6270
# Epoch 227/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6247 - dense_60_loss: 0.6247
# Epoch 228/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6250 - dense_60_loss: 0.6250
# Epoch 229/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6250 - dense_60_loss: 0.6250
# Epoch 230/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6227 - dense_60_loss: 0.6227
# generated text:
# after a time was inter.
#
# Epoch 231/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6249 - dense_60_loss: 0.6249
# Epoch 232/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6235 - dense_60_loss: 0.6235
# Epoch 233/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6221 - dense_60_loss: 0.6221
# Epoch 234/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6206 - dense_60_loss: 0.6206
# Epoch 235/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6221 - dense_60_loss: 0.6221
# Epoch 236/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6193 - dense_60_loss: 0.6193
# Epoch 237/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6221 - dense_60_loss: 0.6221
# Epoch 238/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6200 - dense_60_loss: 0.6200
# Epoch 239/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6203 - dense_60_loss: 0.6203
# Epoch 240/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6194 - dense_60_loss: 0.6194
# generated text:
# after a time it wish have to be the pachess i thing one.
#
# Epoch 241/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6170 - dense_60_loss: 0.6170
# Epoch 242/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6164 - dense_60_loss: 0.6164
# Epoch 243/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6161 - dense_60_loss: 0.6161
# Epoch 244/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6157 - dense_60_loss: 0.6157
# Epoch 245/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6146 - dense_60_loss: 0.6146
# Epoch 246/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6153 - dense_60_loss: 0.6153
# Epoch 247/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6150 - dense_60_loss: 0.6150
# Epoch 248/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6157 - dense_60_loss: 0.6157
# Epoch 249/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6153 - dense_60_loss: 0.6153
# Epoch 250/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6149 - dense_60_loss: 0.6149
# generated text:
# after a time in her his whiting way on a little shoory, when this the booker, and a prizes aliced they with hot wish the graving.
#
# Epoch 251/500
# 17/17 [==============================] - 1s 67ms/step - loss: 0.6164 - dense_60_loss: 0.6164
# Epoch 252/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6138 - dense_60_loss: 0.6138
# Epoch 253/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6134 - dense_60_loss: 0.6134
# Epoch 254/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.6136 - dense_60_loss: 0.6136
# Epoch 255/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6122 - dense_60_loss: 0.6122
# Epoch 256/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6129 - dense_60_loss: 0.6129
# Epoch 257/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6111 - dense_60_loss: 0.6111
# Epoch 258/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6128 - dense_60_loss: 0.6128
# Epoch 259/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6102 - dense_60_loss: 0.6102
# Epoch 260/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6101 - dense_60_loss: 0.6101
# generated text:
# after a time i conto.
#
# Epoch 261/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6091 - dense_60_loss: 0.6091
# Epoch 262/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6087 - dense_60_loss: 0.6087
# Epoch 263/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6102 - dense_60_loss: 0.6102
# Epoch 264/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6103 - dense_60_loss: 0.6103
# Epoch 265/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6094 - dense_60_loss: 0.6094
# Epoch 266/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6094 - dense_60_loss: 0.6094
# Epoch 267/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6080 - dense_60_loss: 0.6080
# Epoch 268/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6080 - dense_60_loss: 0.6080
# Epoch 269/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6074 - dense_60_loss: 0.6074
# Epoch 270/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6066 - dense_60_loss: 0.6066
# generated text:
# after a time that that a little was nishands.
#
# Epoch 271/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6059 - dense_60_loss: 0.6059
# Epoch 272/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6052 - dense_60_loss: 0.6052
# Epoch 273/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6047 - dense_60_loss: 0.6047
# Epoch 274/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6061 - dense_60_loss: 0.6061
# Epoch 275/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6039 - dense_60_loss: 0.6039
# Epoch 276/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6029 - dense_60_loss: 0.6029
# Epoch 277/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6028 - dense_60_loss: 0.6028
# Epoch 278/500
# 17/17 [==============================] - 1s 62ms/step - loss: 0.6019 - dense_60_loss: 0.6019
# Epoch 279/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6011 - dense_60_loss: 0.6011
# Epoch 280/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.6018 - dense_60_loss: 0.6018
# generated text:
# after a time the king tone, and be was the was site the sat i went into a to threally.
#
# Epoch 281/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.6013 - dense_60_loss: 0.6013
# Epoch 282/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6012 - dense_60_loss: 0.6012
# Epoch 283/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6002 - dense_60_loss: 0.6002
# Epoch 284/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5991 - dense_60_loss: 0.5991
# Epoch 285/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5999 - dense_60_loss: 0.5999
# Epoch 286/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5993 - dense_60_loss: 0.5993
# Epoch 287/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.6000 - dense_60_loss: 0.6000
# Epoch 288/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5995 - dense_60_loss: 0.5995
# Epoch 289/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5999 - dense_60_loss: 0.5999
# Epoch 290/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5991 - dense_60_loss: 0.5991
# generated text:
# after a time than this same of atter, and the changer which is a sheept was one a campier out one and to the strat them, wort.
#
# Epoch 291/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5970 - dense_60_loss: 0.5970
# Epoch 292/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5961 - dense_60_loss: 0.5961
# Epoch 293/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5971 - dense_60_loss: 0.5971
# Epoch 294/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5955 - dense_60_loss: 0.5955
# Epoch 295/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5958 - dense_60_loss: 0.5958
# Epoch 296/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5937 - dense_60_loss: 0.5937
# Epoch 297/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5944 - dense_60_loss: 0.5944
# Epoch 298/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5952 - dense_60_loss: 0.5952
# Epoch 299/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5935 - dense_60_loss: 0.5935
# Epoch 300/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5927 - dense_60_loss: 0.5927
# generated text:
# after a time all they.
#
# Epoch 301/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5925 - dense_60_loss: 0.5925
# Epoch 302/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5931 - dense_60_loss: 0.5931
# Epoch 303/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5926 - dense_60_loss: 0.5926
# Epoch 304/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5909 - dense_60_loss: 0.5909
# Epoch 305/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5897 - dense_60_loss: 0.5897
# Epoch 306/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5896 - dense_60_loss: 0.5896
# Epoch 307/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5891 - dense_60_loss: 0.5891
# Epoch 308/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5885 - dense_60_loss: 0.5885
# Epoch 309/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5886 - dense_60_loss: 0.5886
# Epoch 310/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5901 - dense_60_loss: 0.5901
# generated text:
# after a time and.
#
# Epoch 311/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5891 - dense_60_loss: 0.5891
# Epoch 312/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5880 - dense_60_loss: 0.5880
# Epoch 313/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5872 - dense_60_loss: 0.5872
# Epoch 314/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5856 - dense_60_loss: 0.5856
# Epoch 315/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5878 - dense_60_loss: 0.5878
# Epoch 316/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5860 - dense_60_loss: 0.5860
# Epoch 317/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5862 - dense_60_loss: 0.5862
# Epoch 318/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5853 - dense_60_loss: 0.5853
# Epoch 319/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5854 - dense_60_loss: 0.5854
# Epoch 320/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5860 - dense_60_loss: 0.5860
# generated text:
# after a time the reather would.
#
# Epoch 321/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5838 - dense_60_loss: 0.5838
# Epoch 322/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5841 - dense_60_loss: 0.5841
# Epoch 323/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5834 - dense_60_loss: 0.5834
# Epoch 324/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5837 - dense_60_loss: 0.5837
# Epoch 325/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5835 - dense_60_loss: 0.5835
# Epoch 326/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5838 - dense_60_loss: 0.5838
# Epoch 327/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5846 - dense_60_loss: 0.5846
# Epoch 328/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5828 - dense_60_loss: 0.5828
# Epoch 329/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5826 - dense_60_loss: 0.5826
# Epoch 330/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5781 - dense_60_loss: 0.5781
# generated text:
# after a time would began at in the some of little remembled.
#
# Epoch 331/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5826 - dense_60_loss: 0.5826
# Epoch 332/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5817 - dense_60_loss: 0.5817
# Epoch 333/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5801 - dense_60_loss: 0.5801
# Epoch 334/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5815 - dense_60_loss: 0.5815
# Epoch 335/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5817 - dense_60_loss: 0.5817
# Epoch 336/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5810 - dense_60_loss: 0.5810
# Epoch 337/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5802 - dense_60_loss: 0.5802
# Epoch 338/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5804 - dense_60_loss: 0.5804
# Epoch 339/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5804 - dense_60_loss: 0.5804
# Epoch 340/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5810 - dense_60_loss: 0.5810
# generated text:
# after a time the king.
#
# Epoch 341/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5799 - dense_60_loss: 0.5799
# Epoch 342/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5788 - dense_60_loss: 0.5788
# Epoch 343/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5803 - dense_60_loss: 0.5803
# Epoch 344/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5794 - dense_60_loss: 0.5794
# Epoch 345/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5774 - dense_60_loss: 0.5774
# Epoch 346/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5778 - dense_60_loss: 0.5778
# Epoch 347/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5771 - dense_60_loss: 0.5771
# Epoch 348/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5756 - dense_60_loss: 0.5756
# Epoch 349/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5755 - dense_60_loss: 0.5755
# Epoch 350/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5756 - dense_60_loss: 0.5756
# generated text:
# after a time as seen a crumber as wish she said of the king of the door the grool, said in to her their wishe.
#
# Epoch 351/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5732 - dense_60_loss: 0.5732
# Epoch 352/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5755 - dense_60_loss: 0.5755
# Epoch 353/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5768 - dense_60_loss: 0.5768
# Epoch 354/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5770 - dense_60_loss: 0.5770
# Epoch 355/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5761 - dense_60_loss: 0.5761
# Epoch 356/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5763 - dense_60_loss: 0.5763
# Epoch 357/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5749 - dense_60_loss: 0.5749
# Epoch 358/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5736 - dense_60_loss: 0.5736
# Epoch 359/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5755 - dense_60_loss: 0.5755
# Epoch 360/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5755 - dense_60_loss: 0.5755
# generated text:
# after a time of and heard, so the sates had they way.
#
# Epoch 361/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5755 - dense_60_loss: 0.5755
# Epoch 362/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5740 - dense_60_loss: 0.5740
# Epoch 363/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5725 - dense_60_loss: 0.5725
# Epoch 364/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5726 - dense_60_loss: 0.5726
# Epoch 365/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5728 - dense_60_loss: 0.5728
# Epoch 366/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5713 - dense_60_loss: 0.5713
# Epoch 367/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5705 - dense_60_loss: 0.5705
# Epoch 368/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5706 - dense_60_loss: 0.5706
# Epoch 369/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5716 - dense_60_loss: 0.5716
# Epoch 370/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5719 - dense_60_loss: 0.5719
# generated text:
# after a time that were all saye to be of thin, the criving of his shorows i would one the down.
#
# Epoch 371/500
# 17/17 [==============================] - 1s 68ms/step - loss: 0.5710 - dense_60_loss: 0.5710
# Epoch 372/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5701 - dense_60_loss: 0.5701
# Epoch 373/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5699 - dense_60_loss: 0.5699
# Epoch 374/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5701 - dense_60_loss: 0.5701
# Epoch 375/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5690 - dense_60_loss: 0.5690
# Epoch 376/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5701 - dense_60_loss: 0.5701
# Epoch 377/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5691 - dense_60_loss: 0.5691
# Epoch 378/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5676 - dense_60_loss: 0.5676
# Epoch 379/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5659 - dense_60_loss: 0.5659
# Epoch 380/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5668 - dense_60_loss: 0.5668
# generated text:
# after a time in a trone, trick to herself had to five of the way.
#
# Epoch 381/500
# 17/17 [==============================] - 1s 67ms/step - loss: 0.5656 - dense_60_loss: 0.5656
# Epoch 382/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5646 - dense_60_loss: 0.5646
# Epoch 383/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5646 - dense_60_loss: 0.5646
# Epoch 384/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5650 - dense_60_loss: 0.5650
# Epoch 385/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5646 - dense_60_loss: 0.5646
# Epoch 386/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5648 - dense_60_loss: 0.5648
# Epoch 387/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5664 - dense_60_loss: 0.5664
# Epoch 388/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5642 - dense_60_loss: 0.5642
# Epoch 389/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5642 - dense_60_loss: 0.5642
# Epoch 390/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5647 - dense_60_loss: 0.5647
# generated text:
# after a time the gryphon.
#
# Epoch 391/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5625 - dense_60_loss: 0.5625
# Epoch 392/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5643 - dense_60_loss: 0.5643
# Epoch 393/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5618 - dense_60_loss: 0.5618
# Epoch 394/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5634 - dense_60_loss: 0.5634
# Epoch 395/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5640 - dense_60_loss: 0.5640
# Epoch 396/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5607 - dense_60_loss: 0.5607
# Epoch 397/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5620 - dense_60_loss: 0.5620
# Epoch 398/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5629 - dense_60_loss: 0.5629
# Epoch 399/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5609 - dense_60_loss: 0.5609
# Epoch 400/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5619 - dense_60_loss: 0.5619
# generated text:
# after a time bile any the hatter.
#
# Epoch 401/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5619 - dense_60_loss: 0.5619
# Epoch 402/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5609 - dense_60_loss: 0.5609
# Epoch 403/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5601 - dense_60_loss: 0.5601
# Epoch 404/500
# 17/17 [==============================] - 1s 63ms/step - loss: 0.5615 - dense_60_loss: 0.5615
# Epoch 405/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5606 - dense_60_loss: 0.5606
# Epoch 406/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5604 - dense_60_loss: 0.5604
# Epoch 407/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5604 - dense_60_loss: 0.5604
# Epoch 408/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5600 - dense_60_loss: 0.5600
# Epoch 409/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5588 - dense_60_loss: 0.5588
# Epoch 410/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5596 - dense_60_loss: 0.5596
# generated text:
# after a time went one, some she thought in a largered up to be were one the pacting of the mock of at the steen onle.
#
# Epoch 411/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5584 - dense_60_loss: 0.5584
# Epoch 412/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5589 - dense_60_loss: 0.5589
# Epoch 413/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5588 - dense_60_loss: 0.5588
# Epoch 414/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5577 - dense_60_loss: 0.5577
# Epoch 415/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5566 - dense_60_loss: 0.5566
# Epoch 416/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5577 - dense_60_loss: 0.5577
# Epoch 417/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5579 - dense_60_loss: 0.5579
# Epoch 418/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5563 - dense_60_loss: 0.5563
# Epoch 419/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5581 - dense_60_loss: 0.5581
# Epoch 420/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5569 - dense_60_loss: 0.5569
# generated text:
# after a time such, said the mock turtle to herself.
#
# Epoch 421/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5567 - dense_60_loss: 0.5567
# Epoch 422/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5578 - dense_60_loss: 0.5578
# Epoch 423/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5571 - dense_60_loss: 0.5571
# Epoch 424/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5577 - dense_60_loss: 0.5577
# Epoch 425/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5585 - dense_60_loss: 0.5585
# Epoch 426/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5570 - dense_60_loss: 0.5570
# Epoch 427/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5567 - dense_60_loss: 0.5567
# Epoch 428/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5565 - dense_60_loss: 0.5565
# Epoch 429/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5567 - dense_60_loss: 0.5567
# Epoch 430/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5545 - dense_60_loss: 0.5545
# generated text:
# after a time a cack to herself on offest, when all had that in a hands of the great.
#
# Epoch 431/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5553 - dense_60_loss: 0.5553
# Epoch 432/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5560 - dense_60_loss: 0.5560
# Epoch 433/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5575 - dense_60_loss: 0.5575
# Epoch 434/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5552 - dense_60_loss: 0.5552
# Epoch 435/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5558 - dense_60_loss: 0.5558
# Epoch 436/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5558 - dense_60_loss: 0.5558
# Epoch 437/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5546 - dense_60_loss: 0.5546
# Epoch 438/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5541 - dense_60_loss: 0.5541
# Epoch 439/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5547 - dense_60_loss: 0.5547
# Epoch 440/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5544 - dense_60_loss: 0.5544
# generated text:
# after a time a gain, i do you know, alice the could rem this she tand out on it.
#
# Epoch 441/500
# 17/17 [==============================] - 1s 68ms/step - loss: 0.5539 - dense_60_loss: 0.5539
# Epoch 442/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5530 - dense_60_loss: 0.5530
# Epoch 443/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5540 - dense_60_loss: 0.5540
# Epoch 444/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5521 - dense_60_loss: 0.5521
# Epoch 445/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5535 - dense_60_loss: 0.5535
# Epoch 446/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5514 - dense_60_loss: 0.5514
# Epoch 447/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5526 - dense_60_loss: 0.5526
# Epoch 448/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5518 - dense_60_loss: 0.5518
# Epoch 449/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5512 - dense_60_loss: 0.5512
# Epoch 450/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5522 - dense_60_loss: 0.5522
# generated text:
# after a time a large, and said the matter, as is the duchesss of, and her side as the had have sheeld interself they see andeen.
#
# Epoch 451/500
# 17/17 [==============================] - 1s 68ms/step - loss: 0.5522 - dense_60_loss: 0.5522
# Epoch 452/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5521 - dense_60_loss: 0.5521
# Epoch 453/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5496 - dense_60_loss: 0.5496
# Epoch 454/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5514 - dense_60_loss: 0.5514
# Epoch 455/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5512 - dense_60_loss: 0.5512
# Epoch 456/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5504 - dense_60_loss: 0.5504
# Epoch 457/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5507 - dense_60_loss: 0.5507
# Epoch 458/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5505 - dense_60_loss: 0.5505
# Epoch 459/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5517 - dense_60_loss: 0.5517
# Epoch 460/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5508 - dense_60_loss: 0.5508
# generated text:
# after a time when as as they were it said the king of the cound.
#
# Epoch 461/500
# 17/17 [==============================] - 1s 67ms/step - loss: 0.5520 - dense_60_loss: 0.5520
# Epoch 462/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5508 - dense_60_loss: 0.5508
# Epoch 463/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5500 - dense_60_loss: 0.5500
# Epoch 464/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5505 - dense_60_loss: 0.5505
# Epoch 465/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5527 - dense_60_loss: 0.5527
# Epoch 466/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5519 - dense_60_loss: 0.5519
# Epoch 467/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5516 - dense_60_loss: 0.5516
# Epoch 468/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5537 - dense_60_loss: 0.5537
# Epoch 469/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5515 - dense_60_loss: 0.5515
# Epoch 470/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5500 - dense_60_loss: 0.5500
# generated text:
# after a time it was a great in on of-thing of the should again the going the white went on.
#
# Epoch 471/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5508 - dense_60_loss: 0.5508
# Epoch 472/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5484 - dense_60_loss: 0.5484
# Epoch 473/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5483 - dense_60_loss: 0.5483
# Epoch 474/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5488 - dense_60_loss: 0.5488
# Epoch 475/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5476 - dense_60_loss: 0.5476
# Epoch 476/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5480 - dense_60_loss: 0.5480
# Epoch 477/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5485 - dense_60_loss: 0.5485
# Epoch 478/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5498 - dense_60_loss: 0.5498
# Epoch 479/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5472 - dense_60_loss: 0.5472
# Epoch 480/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5461 - dense_60_loss: 0.5461
# generated text:
# after a time when stoop the seen a meenat that shall.
#
# Epoch 481/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5482 - dense_60_loss: 0.5482
# Epoch 482/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5474 - dense_60_loss: 0.5474
# Epoch 483/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5468 - dense_60_loss: 0.5468
# Epoch 484/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5476 - dense_60_loss: 0.5476
# Epoch 485/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5463 - dense_60_loss: 0.5463
# Epoch 486/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5462 - dense_60_loss: 0.5462
# Epoch 487/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5455 - dense_60_loss: 0.5455
# Epoch 488/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5456 - dense_60_loss: 0.5456
# Epoch 489/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5439 - dense_60_loss: 0.5439
# Epoch 490/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5430 - dense_60_loss: 0.5430
# generated text:
# after a time his cook to dince.
#
# Epoch 491/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5443 - dense_60_loss: 0.5443
# Epoch 492/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5442 - dense_60_loss: 0.5442
# Epoch 493/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5427 - dense_60_loss: 0.5427
# Epoch 494/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5457 - dense_60_loss: 0.5457
# Epoch 495/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5441 - dense_60_loss: 0.5441
# Epoch 496/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5463 - dense_60_loss: 0.5463
# Epoch 497/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5454 - dense_60_loss: 0.5454
# Epoch 498/500
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5445 - dense_60_loss: 0.5445
# Epoch 499/500
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5439 - dense_60_loss: 0.5439
# Epoch 500/500
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5460 - dense_60_loss: 0.5460
# generated text:
# after a time the duchs was was the duchess, and all the grybbled of the groppopped.

# %%
# 3 decoders, 3 attention heads
model2 = create_model()
text_gen_callback2 = TextGenerator(maxlen, start_tokens, vocab, print_every=50)
model2.fit(ds, verbose=0, epochs=1000, callbacks=[text_gen_callback2])
# Out:
# generated text:
# after a time the shitt he treast saichte said the wathing her tis, a theres a whad.
#
# generated text:
# after a time tont the was as way, saw in what throw a would thre shingss tulle.
#
# generated text:
# after a time to the hattence all had hight a little be to befure.
#
# generated text:
# after a time of any, some sare though, which i march.
#
# generated text:
# after a time anythe was spil, the mouse.
#
# generated text:
# after a time of the griess, when a book in the word of him her her show whis was on one sigh to to simpeas.
#
# generated text:
# after a time in a little three way more, i though and seem or the work.
#
# generated text:
# after a time of make, i this mouse or way, ant i was ould to the duches went of beathing that with a litted whice.
#
# generated text:
# after a time of minute one shart, and, thos was going to be, as the cand off the timing it was the moutter, or with off.
#
# generated text:
# after a time it mean as the cormouse shouse.
#
# generated text:
# after a time you dance to, that the glames of the sone, who was so it was the march tick turtle was in the gryphon,therse old alle.
#
# generated text:
# after a time the dormouse three little book at alice as said, and said the moment, afred if said a loud, she thing a gain.
#
# generated text:
# after a time in another.
#
# generated text:
# after a time the duchess.
#
# generated text:
# after a time in a large a cats most of the sontime.
#
# generated text:
# after a time of the begran, said the mouse.
#
# generated text:
# after a time you could the duchess the duchess of grent to be sidents about i can a tross which the game of a was she went bow tainnnnnnnnnnnnnnd
#
# generated text:
# after a time it was the white rabbit bittle say, said the hatter, which it in a wonderful say decoxecutied.
#
# generated text:
# after a time then what is deace in herself seve to there say think.
#
# generated text:
# after a time wont, and said the dodon, and hurt saw the court of at the other seem to see thouses a lice off its too cup.

# %%
# 4 decoders, 8 attention heads
line_start3 = "alice "
start_tokens = [encode[char] for char in line_start3]
text_gen_callback3 = TextGenerator(maxlen, start_tokens, vocab, top_k=3, print_every=10)

model3 = create_model()
model3.fit(ds, verbose=0, epochs=1000, callbacks=[text_gen_callback3])
# Out:
# generated text:
# alice the  theth   antou as s o t thee a the the   the   a t   s an t s   t s t  athe   the e  t te hait he thee he  heatou rar  .
#
# generated text:
# alice as t soure ano and in the ase the thenger the she ang thed an thou s se t ishar teris the thither terer the t   ere.
#
# generated text:
# alice she thon the shat to the te the an the wat the wery to in ther the oure wo wond s are o to the the thes thas t reasere t ar .
#
# generated text:
# alice sha thase sa wan son the that sher to sour wast this to bis *
#
# generated text:
# alice the to so aid there tait she wat thit wat was sand, the he to the sousthe whouters the the seat and to wis wen the then t.
#
# generated text:
# alice alice.
#
# generated text:
# alice the weren the do greantly.
#
# generated text:
# alice the mane had a got in the go the was of the said the mistenerse hered whas the drook shat the say sain.
#
# generated text:
# alice andid the matter toice the kis what wit so tremough the dind they was they do to the wat with way the too to the dith.
#
# generated text:
# alice would the moust of the she shought the said int to the withoull tone, the wand the whenting to with that was there wasthe  .
#
# generated text:
# alice the mock at the some sooders to she some the say wink to his she courd.
#
# generated text:
# alice was she withould to grow on the herself said all the marck the cryphor ourt.
#
# generated text:
# alice was alice to that the say, the king, and the grook off a course the worll all the with ous of the would the king the risn.
#
# generated text:
# alice shall the mustion alice, so the dormak turtle hers the was of that of they said, what was nere the who when them of her thers.
#
# generated text:
# alice the mouse the mock a cantled of the should but of the could.
#
# generated text:
# alice was to less to the gryphon, and to his she said the king to have the wasting.
#
# generated text:
# alice was they, were was she the can the cate was trompind off, and was she cand this she same the roome of said.
#
# generated text:
# alice went on ter tried the queen as to the see was neam the dor, and the mouse that on head she dres.
#
# generated text:
# alice said to herself, said the king.
#
# generated text:
# alice was the mock of the could, and that soon.
#
# generated text:
# alice some time the can one on, alice she cary a gettined.
#
# generated text:
# alice the said the kind tat.
#
# generated text:
# alice was the mock treme to be of her with hearts an high sheep.
#
# generated text:
# alice the queen with her said, to alice.
#
# generated text:
# alice they gryphon.
#
# generated text:
# alice asked the could been, said the king.
#
# generated text:
# alice to see of the cong into the hatter.
#
# generated text:
# alice was not the puzzled.
#
# generated text:
# alice asked not a sort too alice the curious when alway onl the of that the was woulder the good began the with door.
#
# generated text:
# alice said aloup to a crould of think the hir seemed on agrion,the wordering in the marchands a she had sirs.
#
# generated text:
# alice say went on, said tea-pakin.
#
# generated text:
# alice think the way on.
#
# generated text:
# alice so no took a partaral was.
#
# generated text:
# alice so see a conted of the mock turtle of sister.
#
# generated text:
# alice said to the gryphon to hear about of the same her the would been which way wonditering a she to see.
#
# generated text:
# alice thought the gryphon, and seemed to talk at the moment one.
#
# generated text:
# alice said to herself, alice with i the such.
#
# generated text:
# alice she tooke of the converse three his spoking and the other was a she was of gotten tree a roor of the crepthat, again.
#
# generated text:
# alice went on of a see, than the other.
#
# generated text:
# alice the queen, said turned alice, the gryphon.
#
# generated text:
# alice asked ture a door shout it.
#
# generated text:
# alice was no there had not time, said the hatter, and the ears was soon, then i march he greard the same of with hire.
#
# generated text:
# alice did not to be scryt of the wood, and, she got belp.
#
# generated text:
# alice watch to go be the way out of sight.
#
# generated text:
# alice asked.
#
# generated text:
# alice so see thought, said alice as she should, and the king of the duchess.
#
# generated text:
# alice was no so my do hand seventemed of the caterpilly, and the wood a court of course.
#
# generated text:
# alice was to go on, she down the back of the back.
#
# generated text:
# alice thought alice tell said the dormouse of the carre.
#
# generated text:
# alice soon alice was asly theyre was they were suddenly to the could, said and the moke took an and the cats bout of the dance.
#
# generated text:
# alice asked if the mock about the toppechop.
#
# generated text:
# alice set those would, the have to her table.
#
# generated text:
# alice and looked at the gryphon the spoke to bacch curious with so she were soup, but the setter sonce in the dormoused.
#
# generated text:
# alice was no the cat, in a loude, and shaking any tried to began and the made in time the cook to the doors.
#
# generated text:
# alice tried they were all round the shriek, and the shate looked at alice.
#
# generated text:
# alice some they witng a coment on the see, said the gryphon.
#
# generated text:
# alice see to get the dormouse that so herself, and the same in the can arrown was of her hand.
#
# generated text:
# alice wastily begins and and dear, and said the cat, and the bance, said alice was the dodod said a began a ding teal them.
#
# generated text:
# alice wated a little at this thing think.
#
# generated text:
# alice was not any tell thing said alice.
#
# generated text:
# alice was not thing she had so the such this trimple of the cabburited to the groun of her set off trying to see wouldnow.
#
# generated text:
# alice this that was no dow, that it was the mock turtle what it was no stange out of that, and the pies.
#
# generated text:
# alice she waited to be something the was got on, have been that would be the lize a growners, at it tremble.
#
# generated text:
# alice was not that the birth where on, and said alice.
#
# generated text:
# alice thought alice looked, at her the mushroom of the see.
#
# generated text:
# alice was all roome of my that all.
#
# generated text:
# alice she was those to down, and that alice.
#
# generated text:
# alice theyve out thise, be the play replied, and alice and the conversation the pirson of had song the crumbat of the workle.
#
# generated text:
# alice then she houghter the rable.
#
# generated text:
# alice so set the could be of the seat in their she cook, and the world drown to size of her wers.
#
# generated text:
# alice was beginning they anyture all tell alice.
#
# generated text:
# alice thinked, and the sat doubthing it as she much took that in a very some of the grock.
#
# generated text:
# alice was thought as well in a three way of little down.
#
# generated text:
# alice thought a graner the piget, and the mock turtle.
#
# generated text:
# alice soon alice thing she wanted her hand tremplae do seemed that that whos to do.
#
# generated text:
# alice said the gryphon.
#
# generated text:
# alice was never soon tree deas.
#
# generated text:
# alice was a good such to the goldown well, sure in the same the way, and the words of the king and the blast abook wold.
#
# generated text:
# alice then, said the cateres in the wind, if you know.
#
# generated text:
# alice did now she went on.
#
# generated text:
# alice was a dear, thats i dont plin said the cook, and the march hare and to here way, it in the ground.
#
# generated text:
# alice said.
#
# generated text:
# alice soon along anges them, and she storied thing to some time with fight in a creeal busion.
#
# generated text:
# alice was side no beginning on tea, the kig, said the king.
#
# generated text:
# alice was that down, she had the mock turtle, with with in a might would glaming the blast the remark.
#
# generated text:
# alice said nexed off, the gryphon and repepeated at trial she went, and watch she had next and must be somenthing the wind.
#
# generated text:
# alice was then.
#
# generated text:
# alice did not gone much please went on, beautiful soup.
#
# generated text:
# alice said the dormouse dreadfuning on the tree.
#
# generated text:
# alice donsnt it walked only chance took to alice, she wand to so she was to be was gettion.
#
# generated text:
# alice said alice, as she was sing down.
#
# generated text:
# alice said alice, and the confusing.
#
# generated text:
# alice did next matt be again.
#
# generated text:
# alice was another, i she had none looked down the othere arme honer the things were to grown at to the sup and his bee tale gromen aaaaaaao
#
# generated text:
# alice said to herself, alices was to three offend as she could to the could bee, that that same when a didnto be the pigen.
#
# generated text:
# alice wasting the gladening white ruled off his she way, the waite tring over she real once twen they and this facle them herple.
#
# generated text:
# alice was beginning sulking in her furmourds, than the duchess was, the moce turtle see as to see the hatter and agum at her ther,*
#
# generated text:
# alice was a great interrupted.
#
# generated text:
# alice down, alice as it, that i cant bustione had the queen of the cant of called them she hand a soners.
#
# generated text:
# alice was sigh think.
